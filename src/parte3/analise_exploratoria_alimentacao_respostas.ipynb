# %%
from funcoes_auxiliares import *

pd.options.display.float_format = "{:.2f}".format
pd.options.display.max_rows = 6

# %%
#definições básicas explicadas no arquivo de análise exploratória
qtd_top_itens = 5
pd.options.display.max_rows = qtd_top_itens + 1
cores = ['green', 'yellow', 'orange', 'red', 'blue', 'purple']

# %% [markdown]
# ## Dataset de despesas com alimentação

# %% [markdown]
# ### Plotando então os dados de top 5 para renda da mesma forma que a análise exploratória, vamos utilizá-lo como base para responder algumas perguntas

# %%
df = get_df_estado_alimentacao("MG")
plot_todos_graficos_barras_lista_top_N_itens(df, qtd_top_itens, cores)

# %% [markdown]
# # Vamos agora tentar responder algumas perguntas propostas

# %% [markdown]
# ## Consigo medir os hábitos de consumo da população baseados em sua classe?
#
# Sim, conseguimos claramente a partir do top 5 de gastos da população verificar quais os consumos mais comuns
# para cada população de acordo com a renda da família.
#
# Apesar disso, podemos perceber que os gastos principais são bastante semelhantes independente da renda, visto que os principais gastos são com alimentação, transporte e moradia.

# %% [markdown]
# ## Consigo saber com o que a população de cada classe mais gasta?
#
# Novamente, conseguimos responder essa pergunta apenas olhando para o top 5 gastos das famílias e suas rendas. Por exemplo, o quanto aluguel é uma desepesa mais constante para famílias com a renda um pouco mais baixa enquanto nem aparece nas maiores rendas.
#
# Outro exemplo são os gastos com outras despesas correntes, que é predominante nas famílias mais ricas e nem aparece em famílias mais pobres

# %% [markdown]
# ## Consigo medir os hábitos de consumo da população baseados em sua localização geográfica?
#
# Vamos verificar...

# %%
#plotando para São Paulo
df = get_df_estado_alimentacao("SP")
plot_todos_graficos_barras_lista_top_N_itens(df, qtd_top_itens, cores)

# %%
#plotando para o Rio Grande do Sul
df = get_df_estado_alimentacao("RS")
plot_todos_graficos_barras_lista_top_N_itens(df, qtd_top_itens, cores)

# %% [markdown]
# Como podemos perceber, poderíamos continuar plotando dados para outros estados aqui e provavelmente obteríamos resultados um pouco distintos.
#
# Podemos notar por exemplo que o investimento em ativos para rendas maiores no RS é mais evidente que em MG e SP.
#
# Analogamente, os aluguéis em SP são muito mais comuns para classes mais altas que no RS e em MG, dentre outras informações que podem ser extraídas sobre essa pergunta.
#
# Logo, podemos identificar os hábitos de consumo baeados na localização.

# %% [markdown]
# ## Os hábitos de consumo das regiões se correlacionam com a classe social dos indivíduos?
#
# Visualmente falando é difícil responder, porém podemos notar algumas semelhanças. Por exemplo:

# %%
df = get_df_estado_alimentacao("PR")
plot_grafico_barras_lista_top_N_itens(df, 'Mais de 14310 a 23850', qtd_top_itens, 'purple')

# %%
df = get_df_estado_alimentacao("RS")
plot_grafico_barras_lista_top_N_itens(df, 'Mais de 14310 a 23850', qtd_top_itens, 'purple')

# %%
df = get_df_estado_alimentacao("PA")
plot_grafico_barras_lista_top_N_itens(df, 'Mais de 14310 a 23850', qtd_top_itens, 'purple')

# %%
df = get_df_estado_alimentacao("AM")
plot_grafico_barras_lista_top_N_itens(df, 'Mais de 14310 a 23850', qtd_top_itens, 'purple')

# %% [markdown]
# Ou seja, apesar de algumas categorias serem semelhantes, estados mais do Norte/Nordeste possuem características um pouco distintas de estados Sudeste/Sul.
#
# Por exemplo. aluguel é uma despesa um pouco mais presente em estados do Norte/Nordeste que estados do Sul.

# %% [markdown]
# ## É possível identificar padrões de consumo por região e aplicar publicidade exclusiva?
#
# Como pudemos analisar nos gráficos acima, sim, é possível identificar quais itens são mais comprados de acordo com a renda e ou região. Ou seja, antes de se instalar uma loja ou fábrica, ou direcionar uma campanha publicitária, pode-se analisar se os gastos do público alvo naquela região são relevantes para o seu produto.

# %% [markdown]
# ## É possível descobrir possíveis áreas em alta (com algum padrão de consumo) que propulsionam algum nicho de mercado?
#
# Sim, podemos por exemplo perceber que independente da renda ou classe social, bem como independente de região, os gastos com habitação são bastante altos, viabilizando por exemplo o nicho de construções civís.
